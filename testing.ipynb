# %%
import testpackage

# %%
testpackage.add_numbers.add(2.3, 4)

help(testpackage.add_numbers.add)
# Out:
# Help on function add in module testpackage.add_numbers:
#
# add(a, b)
#     Adds two numbers and returns the result rounded to the nearest integer.
#
#     Args:
#         a (float): The first number.
#         b (float): The second number.
#
#     Returns:
#         int: The sum of a and b, rounded to the nearest integer.
